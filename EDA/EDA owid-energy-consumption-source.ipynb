# %% [markdown]
# # EDA owid-energy-consumption-source

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
tabla = pd.read_csv('owid-energy-consumption-source.csv')
tabla.dropna().head(10)
# Out:
#         country  year iso_code   population           gdp  \
# 1015  Argentina  2011      ARG   41320496.0  8.359705e+11
# 1016  Argentina  2012      ARG   41755188.0  8.274048e+11
# 1017  Argentina  2013      ARG   42196036.0  8.473051e+11
# 1018  Argentina  2014      ARG   42637508.0  8.259815e+11
# 1019  Argentina  2015      ARG   43075416.0  8.478550e+11
# 1020  Argentina  2016      ARG   43508460.0  8.283729e+11
# 2863     Brazil  2013      BRA  201035904.0  3.112906e+12
# 2864     Brazil  2014      BRA  202763744.0  3.128573e+12
# 2865     Brazil  2015      BRA  204471760.0  3.270706e+12
# 2866     Brazil  2016      BRA  206163056.0  2.889037e+12
#
#       biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 1015                   47.637                    2.822
# 1016                   23.473                    2.053
# 1017                   10.228                    1.104
# 1018                   16.710                    1.989
# ...

# %%
tabla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22343 entries, 0 to 22342
# Columns: 128 entries, country to wind_share_energy
# dtypes: float64(125), int64(1), object(2)
# memory usage: 21.8+ MB

# %%
tabla.describe()
# Out:
#                year    population           gdp  biofuel_cons_change_pct  \
# count  22343.000000  1.797100e+04  1.111300e+04              1006.000000
# mean    1973.844291  1.054007e+08  3.585114e+11                36.359683
# std       34.621266  4.597508e+08  2.411179e+12               239.662846
# min     1900.000000  1.606000e+03  1.642060e+08              -100.000000
# 25%     1946.000000  1.735172e+06  1.365898e+10                -0.049000
# 50%     1984.000000  7.089486e+06  4.167411e+10                 7.753500
# 75%     2003.000000  2.574816e+07  1.744295e+11                24.199750
# max     2021.000000  7.874956e+09  1.136302e+14              5659.328000
#
#        biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# count              1545.000000               952.000000          1584.000000
# mean                  3.030219               160.110105            41.526071
# std                  10.917918               271.550385           117.621518
# ...

# %%
# Verificamos las columnas con 80% o más de valores faltantes
total = len(tabla)
for column in tabla.columns:
    faltantes = len(tabla[tabla[column].isnull()])
    percent = faltantes/total *100
    if percent >= 80:
        print(column, percent)
# Out:
# biofuel_cons_change_pct 95.49747124379
# biofuel_cons_change_twh 93.08508257619836
# biofuel_cons_per_capita 95.73915767801996
# biofuel_consumption 92.91053126258784
# biofuel_share_energy 92.91053126258784
# nuclear_cons_change_pct 88.94060779662534
# other_renewables_cons_change_pct 83.11327932685853
# solar_cons_change_pct 90.09980754598756
# wind_cons_change_pct 88.72129973593519

# %% [markdown]
# Podríamos eliminar esas columnas

# %% [markdown]
# ## Observaciones
# 1) Las columnas que aparecen aportan información muy relacionada a "energyco2.csv"
# 2) Podríamos ignorarlos
