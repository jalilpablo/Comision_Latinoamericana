# %%
import pandas as pd 
import numpy as np
import matplotlib as plt 
import seaborn as sns

# %%
df = pd.read_csv('temperatures.csv', index_col=0, encoding='latin-1')

# %%
df
# Out:
#         ATG    ARG    BHS    BRB    BLZ    BOL    BRA   CHL    COL    CRI  \
# year
# 1901  26.23  15.20  23.25  25.90  24.93  21.23  24.91  9.87  24.49  24.28
# 1902  25.87  14.84  24.07  25.75  25.14  21.12  25.04  9.34  24.39  24.28
# 1903  25.98  14.49  23.79  25.78  25.12  20.72  24.87  9.12  24.42  24.28
# 1904  25.50  14.72  23.77  25.55  24.98  20.59  24.66  9.40  24.42  24.28
# 1905  25.83  14.34  24.35  25.70  25.09  20.92  24.84  8.98  24.36  24.28
# ...     ...    ...    ...    ...    ...    ...    ...   ...    ...    ...
# 2017  27.36  15.52  25.69  26.75  26.09  20.97  25.77  9.87  25.11  24.92
# 2018  27.03  15.20  25.47  26.44  25.53  20.56  25.59  9.56  25.04  24.53
# 2019  27.43  15.18  25.96  26.71  26.05  20.90  25.94  9.66  25.42  24.89
# 2020  27.44  15.52  25.99  26.80  26.38  21.35  25.93  9.97  25.36  25.08
# 2021  27.33  15.40  25.50  26.64  26.15  20.82  25.58  9.88  24.97  24.94
#
#       ...    PRY    PER    DOM    KNA    VCT    LCA    SUR    TTO    URY  \
# year  ...
# 1901  ...  24.12  19.22  23.67  26.51  25.41  26.23  26.65  25.93  17.33
# 1902  ...  24.25  19.21  23.35  26.11  25.17  26.02  26.66  25.66  17.37
# 1903  ...  23.57  19.02  23.41  26.21  25.24  26.07  26.64  25.69  16.97
# 1904  ...  23.53  18.93  22.99  25.71  24.99  25.79  26.24  25.39  16.89
# 1905  ...  23.55  19.16  23.40  26.08  25.14  25.97  26.47  25.55  16.68
# ...   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2017  ...  24.35  19.98  24.69  27.64  26.32  27.14  26.75  26.74  18.78
# 2018  ...  23.74  19.58  24.57  27.32  25.97  26.79  26.53  26.38  18.23
# 2019  ...  24.25  19.89  24.89  27.75  26.26  27.10  26.84  26.69  18.14
# 2020  ...  24.62  19.95  24.86  27.73  26.33  27.18  26.90  26.78  18.12
# 2021  ...  24.01  19.79  24.70  27.61  26.17  27.04  26.56  26.54  18.06
#
#         VEN
# year
# 1901  25.04
# 1902  24.69
# 1903  24.77
# 1904  24.64
# 1905  24.58
# ...     ...
# 2017  25.88
# 2018  25.57
# 2019  25.87
# 2020  25.93
# 2021  25.61
#
# [121 rows x 32 columns]

# %% [markdown]
# Identificación de tipos de datos

# %%
df.dtypes
# Out:
# ATG    float64
# ARG    float64
# BHS    float64
# BRB    float64
# BLZ    float64
# BOL    float64
# BRA    float64
# CHL    float64
# COL    float64
# CRI    float64
# CUB    float64
# DMA    float64
# ECU    float64
# SLV    float64
# GTM    float64
# GUY    float64
# HTI    float64
# HND    float64
# JAM    float64
# MEX    float64
# NIC    float64
# PAN    float64
# PRY    float64
# PER    float64
# DOM    float64
# KNA    float64
# VCT    float64
# LCA    float64
# SUR    float64
# TTO    float64
# URY    float64
# VEN    float64
# dtype: object

# %% [markdown]
# Tamaño del dataset

# %%
df.shape
# Out:
# (121, 32)

# %% [markdown]
# Ver estadísticas del dataset

# %%
df.describe()
# Out:
#               ATG         ARG         BHS         BRB         BLZ         BOL  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    26.405785   14.818264   24.566033   26.011322   25.168430   20.788347
# std      0.628164    0.355874    0.546764    0.457145    0.430488    0.302821
# min     25.150000   14.000000   23.110000   25.380000   23.940000   19.930000
# 25%     25.940000   14.580000   24.180000   25.620000   24.850000   20.560000
# 50%     26.340000   14.820000   24.510000   25.900000   25.110000   20.790000
# 75%     26.960000   15.060000   24.900000   26.410000   25.380000   21.000000
# max     27.510000   15.530000   26.140000   27.090000   26.380000   21.550000
#
#               BRA         CHL         COL         CRI  ...         PRY  \
# count  121.000000  121.000000  121.000000  121.000000  ...  121.000000
# mean    24.901736    9.267851   24.629917   24.433554  ...   23.742066
# std      0.399038    0.294520    0.336805    0.342077  ...    0.417221
# min     24.200000    8.670000   23.980000   23.700000  ...   22.700000
# 25%     24.640000    9.030000   24.400000   24.260000  ...   23.450000
# 50%     24.810000    9.280000   24.580000   24.280000  ...   23.740000
# 75%     25.080000    9.460000   24.820000   24.730000  ...   24.010000
# max     25.970000    9.970000   25.650000   25.160000  ...   24.780000
#
#               PER         DOM         KNA         VCT         LCA         SUR  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    19.460909   23.819504   26.674380   25.519752   26.352231   26.241157
# std      0.419321    0.593711    0.655034    0.496639    0.491327    0.347650
# min     18.550000   22.600000   25.350000   24.790000   25.640000   25.520000
# 25%     19.210000   23.350000   26.210000   25.080000   25.920000   25.960000
# 50%     19.450000   23.850000   26.630000   25.410000   26.240000   26.220000
# 75%     19.720000   24.320000   27.250000   25.970000   26.760000   26.470000
# max     20.680000   25.050000   27.820000   26.600000   27.400000   27.080000
#
#               TTO         URY         VEN
# count  121.000000  121.000000  121.000000
# mean    25.969504   17.570661   25.197107
# std      0.457218    0.464216    0.444011
# min     25.210000   16.470000   24.490000
# 25%     25.560000   17.250000   24.850000
# 50%     25.930000   17.570000   25.180000
# 75%     26.350000   17.930000   25.560000
# max     26.980000   18.780000   26.300000
#
# [8 rows x 32 columns]

# %% [markdown]
# Busco nulos

# %%
df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# ATG    0
# ARG    0
# BHS    0
# BRB    0
# BLZ    0
# BOL    0
# BRA    0
# CHL    0
# COL    0
# CRI    0
# CUB    0
# DMA    0
# ECU    0
# SLV    0
# GTM    0
# GUY    0
# HTI    0
# HND    0
# JAM    0
# MEX    0
# NIC    0
# PAN    0
# PRY    0
# PER    0
# DOM    0
# KNA    0
# VCT    0
# LCA    0
# SUR    0
# TTO    0
# URY    0
# VEN    0
# dtype: int64

# %%
df['ARG'].hist(bins=25)
# Out:
# <AxesSubplot:>

# %% [markdown]
# En este caso el pico está en el 100 pero desde el 0 al 100 hay pocos datos que se reparten uniformemente.

# %%
print(df.boxplot(column='MEX'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
sns.boxplot(x=df['COL'])
# Out:
# <AxesSubplot:xlabel='COL'>

# %%
sns.countplot(df.BRA)
# Out:
# c:\Users\AliPC\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='BRA', ylabel='count'>
