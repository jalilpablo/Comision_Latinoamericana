# %%
import pandas as pd 
import numpy as np
import matplotlib as plt 
import plotly.graph_objects as go
import plotly.express as px
import seaborn as sns

# %%
df = pd.read_csv('temperatures.csv', index_col=0, encoding='latin-1')

# %%
df
# Out:
#       temperatura codigo
# year
# 1901        26.23    ATG
# 1902        25.87    ATG
# 1903        25.98    ATG
# 1904        25.50    ATG
# 1905        25.83    ATG
# ...           ...    ...
# 2017        25.88    VEN
# 2018        25.57    VEN
# 2019        25.87    VEN
# 2020        25.93    VEN
# 2021        25.61    VEN
#
# [3872 rows x 2 columns]

# %% [markdown]
# Identificación de tipos de datos

# %%
df.dtypes
# Out:
# temperatura    float64
# codigo          object
# dtype: object

# %% [markdown]
# Tamaño del dataset

# %%
df.shape
# Out:
# (3872, 2)

# %% [markdown]
# Ver estadísticas del dataset

# %%
df.describe()
# Out:
#        temperatura
# count  3872.000000
# mean     23.520331
# std       3.731109
# min       8.670000
# 25%      23.220000
# 50%      24.810000
# 75%      25.660000
# max      27.820000

# %%
df['codigo'].unique()
# Out:
# array(['ATG', 'ARG', 'BHS', 'BRB', 'BLZ', 'BOL', 'BRA', 'CHL', 'COL',
#        'CRI', 'CUB', 'DMA', 'ECU', 'SLV', 'GTM', 'GUY', 'HTI', 'HND',
#        'JAM', 'MEX', 'NIC', 'PAN', 'PRY', 'PER', 'DOM', 'KNA', 'VCT',
#        'LCA', 'SUR', 'TTO', 'URY', 'VEN'], dtype=object)

# %% [markdown]
# Busco nulos

# %%
df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# temperatura    0
# codigo         0
# dtype: int64

# %%
df['temperatura'].hist(bins=25)
# Out:
# <AxesSubplot:>

# %% [markdown]
# En este caso el pico está en el 100 pero desde el 0 al 100 hay pocos datos que se reparten uniformemente.

# %%
print(df.boxplot(column='temperatura'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
sns.boxplot(x=df['temperatura'])
# Out:
# <AxesSubplot:xlabel='temperatura'>

# %%
sns.countplot(df.temperatura)
# Out:
# c:\Users\AliPC\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='temperatura', ylabel='count'>

# %%
tabla_g = df
tabla_g.reset_index(inplace=True)
fig = px.line(tabla_g, 'year', 'temperatura', color='codigo', title='Temperatura en Latinoamerica')
fig.show()
