# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
table = pd.read_csv('Temperatures.csv')
table
# Out:
#       year  temperatura codigo
# 0     1901        26.23    ATG
# 1     1902        25.87    ATG
# 2     1903        25.98    ATG
# 3     1904        25.50    ATG
# 4     1905        25.83    ATG
# ...    ...          ...    ...
# 3867  2017        25.88    VEN
# 3868  2018        25.57    VEN
# 3869  2019        25.87    VEN
# 3870  2020        25.93    VEN
# 3871  2021        25.61    VEN
#
# [3872 rows x 3 columns]

# %%
fig = px.line(table, 'year', 'temperatura', color= 'codigo')
fig.show()
